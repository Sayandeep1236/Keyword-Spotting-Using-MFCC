# %% [markdown]
# KEYWORD SPOTTING USING MFCC IN TENSORFLOW

# %% [markdown]
# To run this notebook, make sure to have Python 3.10.0 installed.
#
# To install Python 3.10.0,
# 1) Go to the link below:
#   https://www.python.org/downloads/release/python-3100/
# 2) Click on the suitable installer (If using Windows, download Windows installer (64-bit))
# 3) As you run the installer, check on the box "Add Python 3.10 to PATH" and then install

# %%
# !pip install tensorflow==2.13.0 librosa scikit-learn numpy pyaudio matplotlib  IPython seaborn pathlib
# Out:
# Requirement already satisfied: tensorflow==2.13.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (2.13.0)
# Requirement already satisfied: librosa in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (0.10.1)
# Requirement already satisfied: scikit-learn in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (1.24.3)
# Requirement already satisfied: pyaudio in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (0.2.14)
# Requirement already satisfied: matplotlib in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: IPython in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (8.17.2)
# Requirement already satisfied: seaborn in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (0.13.0)
# Requirement already satisfied: pathlib in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.59.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.23.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.11.3)
# Requirement already satisfied: joblib>=0.14 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (5.13.0)
# Requirement already satisfied: exceptiongroup in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (1.1.3)
# Requirement already satisfied: colorama in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.0->librosa) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: wcwidth in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython) (0.2.9)
# Requirement already satisfied: cffi>=1.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from stack-data->IPython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from stack-data->IPython) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.41.3)
# Requirement already satisfied: pycparser in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sayan\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.2.2)

# %% [markdown]
# Importing the necessary libraries

# %%
import os

import pathlib

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import pickle
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

import pyaudio

import time

import librosa

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,BatchNormalization, LSTM,Reshape,AveragePooling2D, GlobalAveragePooling2D
from IPython import display

# %% [markdown]
# LOADING FILES AND MAKING MFCCS:
# We go through each directory in the path of the folder given, and assign each audio mfcc with the corresponding folder names in the 'labels' variable

# %%
def load_wav_files(folder_path):
    data = []
    labels = []
    wave=[]
    label_list=[]
    for label in os.listdir(folder_path):
        label_path = os.path.join(folder_path, label)
        if os.path.isdir(label_path):
            for filename in os.listdir(label_path):
                file_path = os.path.join(label_path, filename)
                if filename.endswith(".wav"):
                    # Load audio file
                    audio_data, _ = librosa.load(file_path, sr=16000) # Sample rate is considered as 16kHz
                    audio_data = librosa.util.fix_length(audio_data, size=16000)
                    mfccs = librosa.feature.mfcc(y=audio_data, sr=16000, n_mfcc=13)# No. of mfccs for each audio is taken as 13 with sampling rate as 16kHz
                    wave.append(audio_data)
                    data.append(mfccs)
                    labels.append(label)
                    label_list.append(label) if label not in label_list else None
    return wave,data,labels,label_list

# Specify the root folder containing subfolders with audio files
root_folder = str(input())# Input the PATH containing the audio files with their respective labels from the user
root_folder = pathlib.Path(root_folder)
wave,mfcc, labels,label_list = load_wav_files(root_folder)
# Out:
#  C:\Users\sayan\Desktop\SpeechDeepTest\data\mini_speech_commands

# %% [markdown]
# The following labels are detected

# %%
print(label_list)
# Out:
# ['go', 'noise', 'off', 'on', 'stop', 'unknown']

# %%
# Small demonstration on how the waveforms look like with their corresponding MFCCs
for i in range(10): 
    time = np.arange(0, len(wave[i])) / 16000
    
    # Plot the waveform
    plt.figure(figsize=(10, 4))
    plt.plot(time, wave[i], linewidth=0.5)
    plt.title(str(labels[i]))
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()
    print('Audio playback')
    display.display(display.Audio(wave[i], rate=16000))
    plt.figure(figsize=(10,4))
    librosa.display.specshow(mfcc[i], 
                         x_axis="time",sr=16000,
                         )
    plt.colorbar(format="%+2.f")
    plt.show()
# Out:
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Preparing the training and testing datasets

# %%
# We use Label Encoder to convert categorical data to numerical data
label_encoder = LabelEncoder()
numeric_labels = label_encoder.fit_transform(labels)

# %%
# Making Training and Testing datasets with a 80/20 split and shuffling enabled
X_train, X_test, y_train, y_test = train_test_split(
    mfcc, numeric_labels, test_size=0.2, random_state=42
)

# %%
# Making numpy array for reshaping
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
# Dimensions  will be ( Number of mfccs list, number of mfccs in each list, time frames for each mfcc list, extra dimension to act as a channel)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %%
X_train.shape
# Out:
# (17704, 13, 32, 1)

# %%
X_test.shape
# Out:
# (4426, 13, 32, 1)

# %%
# Dividing the testing dataset into validation and testing 
X_test,X_val=X_test[len(X_test)//2:],X_test[:len(X_test)//2]
y_test,y_val=y_test[len(y_test)//2:],y_test[:len(y_test)//2]
print(X_test.shape,X_val.shape)
print(y_test.shape,y_val.shape)
# Out:
# (2213, 13, 32, 1) (2213, 13, 32, 1)
# (2213,) (2213,)

# %%
# Making the model which is essentially a CNN with LSTM
# In this  model, Global Average Pooling is used to make an average off all the features  extracted
model = Sequential()

#FEATURE EXTRACTION

# to extract spatial features
model.add(Conv2D(32, 3, activation='relu', padding='same', input_shape=(X_train.shape[1], X_train.shape[2], 1),kernel_regularizer=l2(0.0001))) #L2 regularization adds a penalty term to the loss function, which is proportional to the square of the magnitude of the weights 
model.add(BatchNormalization()) # To normalize the data by re-centering and re-scaling
model.add(Conv2D(64, 3, activation='relu', padding='same',kernel_regularizer=l2(0.0001)))

model.add(Conv2D(128, 3, activation='relu', padding='same',kernel_regularizer=l2(0.0001)))

model.add(GlobalAveragePooling2D())# Give an output of 128 features in a row, averaged over the 128 filtered outputs we get from the previous Conv2D layer
model.add(Dropout(0.2))


model.add(Reshape((-1, 128)))  

model.add(LSTM(64, return_sequences=True)) # Helps in retaining the temporal dependencies and memorizes it for further training sets 

#CLASSIFICATION
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(len(set(numeric_labels)), activation='softmax')) # gives the probabilites of each label

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Train the model

y=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100,callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=10),batch_size=64,)

# The number of epochs used here is 100, hence it takes a long time to have it trained
# Out:
# Epoch 1/100
# 277/277 [==============================] - 20s 66ms/step - loss: 1.6304 - accuracy: 0.2488 - val_loss: 1.5535 - val_accuracy: 0.2630
# Epoch 2/100
# 277/277 [==============================] - 16s 59ms/step - loss: 1.5147 - accuracy: 0.3199 - val_loss: 1.4652 - val_accuracy: 0.3574
# Epoch 3/100
100
# 277/277 [==============================] - 18s 64ms/step - loss: 0.3107 - accuracy: 0.8995 - val_loss: 0.3014 - val_accuracy: 0.9042
# Epoch 30/100
# 277/277 [==============================] - 17s 60ms/step - loss: 0.3083 - accuracy: 0.9035 - val_loss: 0.2853 - val_accuracy: 0.9083
# Epoch 31/100
# 277/277 [==============================] - 17s 60ms/step - loss: 0.3038 - accuracy: 0.9022 - val_loss: 0.2921 - val_accuracy: 0.9056
# Epoch 32/100
# 277/277 [==============================] - 17s 60ms/step - loss: 0.2935 - accuracy: 0.9046 - val_loss: 0.2759 - val_accuracy: 0.9092
# Epoch 33/100
# 277/277 [==============================] - 17s 61ms/step - loss: 0.2890 - accuracy: 0.9069 - val_loss: 0.2740 - val_accuracy: 0.9141
# Epoch 34/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.2812 - accuracy: 0.9094 - val_loss: 0.2728 - val_accuracy: 0.9191
# Epoch 35/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.2706 - accuracy: 0.9127 - val_loss: 0.2657 - val_accuracy: 0.9169
# Epoch 36/100
# 277/277 [==============================] - 17s 63ms/step - loss: 0.2732 - accuracy: 0.9136 - val_loss: 0.2653 - val_accuracy: 0.9119
# Epoch 37/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.2705 - accuracy: 0.9106 - val_loss: 0.2658 - val_accuracy: 0.9128
# Epoch 38/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.2636 - accuracy: 0.9152 - val_loss: 0.2577 - val_accuracy: 0.9191
# Epoch 39/100
# 277/277 [==============================] - 18s 64ms/step - loss: 0.2583 - accuracy: 0.9184 - val_loss: 0.2474 - val_accuracy: 0.9191
# Epoch 40/100
# 277/277 [==============================] - 17s 63ms/step - loss: 0.2563 - accuracy: 0.9195 - val_loss: 0.2484 - val_accuracy: 0.9196
# Epoch 41/100
# 277/277 [==============================] - 17s 61ms/step - loss: 0.2458 - accuracy: 0.9224 - val_loss: 0.2475 - val_accuracy: 0.9218
# Epoch 42/100
# 277/277 [==============================] - 17s 61ms/step - loss: 0.2450 - accuracy: 0.9217 - val_loss: 0.2512 - val_accuracy: 0.9209
# Epoch 43/100
# 277/277 [==============================] - 17s 61ms/step - loss: 0.2405 - accuracy: 0.9254 - val_loss: 0.2393 - val_accuracy: 0.9227
# Epoch 44/100
# 277/277 [==============================] - 17s 63ms/step - loss: 0.2400 - accuracy: 0.9252 - val_loss: 0.2380 - val_accuracy: 0.9241
# Epoch 45/100
# 277/277 [==============================] - 18s 64ms/step - loss: 0.2336 - accuracy: 0.9258 - val_loss: 0.2341 - val_accuracy: 0.9232
# Epoch 46/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.2314 - accuracy: 0.9264 - val_loss: 0.2292 - val_accuracy: 0.9254
# Epoch 47/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.2272 - accuracy: 0.9271 - val_loss: 0.2319 - val_accuracy: 0.9232
# Epoch 48/100
# 277/277 [==============================] - 17s 61ms/step - loss: 0.2265 - accuracy: 0.9289 - val_loss: 0.2331 - val_accuracy: 0.9263
# Epoch 49/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.2196 - accuracy: 0.9309 - val_loss: 0.2329 - val_accuracy: 0.9304
# Epoch 50/100
# 277/277 [==============================] - 17s 63ms/step - loss: 0.2152 - accuracy: 0.9334 - val_loss: 0.2365 - val_accuracy: 0.9205
# Epoch 51/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.2219 - accuracy: 0.9309 - val_loss: 0.2580 - val_accuracy: 0.9173
# Epoch 52/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.2160 - accuracy: 0.9322 - val_loss: 0.2312 - val_accuracy: 0.9286
# Epoch 53/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.2098 - accuracy: 0.9356 - val_loss: 0.2211 - val_accuracy: 0.9295
# Epoch 54/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.2111 - accuracy: 0.9336 - val_loss: 0.2288 - val_accuracy: 0.9318
# Epoch 55/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.2059 - accuracy: 0.9365 - val_loss: 0.2427 - val_accuracy: 0.9245
# Epoch 56/100
# 277/277 [==============================] - 18s 66ms/step - loss: 0.2035 - accuracy: 0.9377 - val_loss: 0.2160 - val_accuracy: 0.9313
# Epoch 57/100
# 277/277 [==============================] - 18s 64ms/step - loss: 0
100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.1472 - accuracy: 0.9576 - val_loss: 0.1913 - val_accuracy: 0.9440
# Epoch 85/100
# 277/277 [==============================] - 18s 64ms/step - loss: 0.1460 - accuracy: 0.9565 - val_loss: 0.1954 - val_accuracy: 0.9462
# Epoch 86/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.1458 - accuracy: 0.9573 - val_loss: 0.1990 - val_accuracy: 0.9404
# Epoch 87/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1378 - accuracy: 0.9596 - val_loss: 0.1872 - val_accuracy: 0.9440
# Epoch 88/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1391 - accuracy: 0.9589 - val_loss: 0.1854 - val_accuracy: 0.9467
# Epoch 89/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.1380 - accuracy: 0.9612 - val_loss: 0.1841 - val_accuracy: 0.9462
# Epoch 90/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1387 - accuracy: 0.9585 - val_loss: 0.1963 - val_accuracy: 0.9404
# Epoch 91/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1354 - accuracy: 0.9610 - val_loss: 0.1812 - val_accuracy: 0.9449
# Epoch 92/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.1341 - accuracy: 0.9603 - val_loss: 0.2105 - val_accuracy: 0.9327
# Epoch 93/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1343 - accuracy: 0.9623 - val_loss: 0.1859 - val_accuracy: 0.9489
# Epoch 94/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1319 - accuracy: 0.9603 - val_loss: 0.1852 - val_accuracy: 0.9480
# Epoch 95/100
# 277/277 [==============================] - 17s 62ms/step - loss: 0.1303 - accuracy: 0.9607 - val_loss: 0.1777 - val_accuracy: 0.9489
# Epoch 96/100
# 277/277 [==============================] - 17s 63ms/step - loss: 0.1289 - accuracy: 0.9631 - val_loss: 0.1960 - val_accuracy: 0.9435
# Epoch 97/100
# 277/277 [==============================] - 18s 63ms/step - loss: 0.1283 - accuracy: 0.9620 - val_loss: 0.1981 - val_accuracy: 0.9489
# Epoch 98/100
# 277/277 [==============================] - 18s 66ms/step - loss: 0.1257 - accuracy: 0.9635 - val_loss: 0.1842 - val_accuracy: 0.9485
# Epoch 99/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.1251 - accuracy: 0.9641 - val_loss: 0.1747 - val_accuracy: 0.9485
# Epoch 100/100
# 277/277 [==============================] - 18s 65ms/step - loss: 0.1273 - accuracy: 0.9630 - val_loss: 0.1749 - val_accuracy: 0.9507

# %% [markdown]
# MODEL METRICS

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc * 100:.2f}%')
# Out:
# 70/70 [==============================] - 1s 12ms/step - loss: 0.1851 - accuracy: 0.9453
# Test accuracy: 94.53%

# %%
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error (RMSE): ', mse)
print('Root Mean Squared Error (RMSE): ', (mse)**0.5)
# Out:
# Mean Squared Error (RMSE):  0.5508359692724808
# Root Mean Squared Error (RMSE):  0.7421832450766326

# %%
print('Classification report:')
print(classification_report(y_test,y_pred))
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       392
#            1       0.95      0.97      0.96       279
#            2       0.94      0.95      0.95       361
#            3       0.96      0.93      0.95       413
#            4       0.97      0.97      0.97       407
#            5       0.94      0.89      0.91       361
#
#     accuracy                           0.95      2213
#    macro avg       0.95      0.95      0.95      2213
# weighted avg       0.95      0.95      0.95      2213

# %%
#Model metrics
metrics = y.history
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(y.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.ylim([0, max(plt.ylim())])
plt.xlabel('Epoch')
plt.ylabel('Loss [CrossEntropy]')

plt.subplot(1,2,2)
plt.plot(y.epoch, 100*np.array(metrics['accuracy']), 100*np.array(metrics['val_accuracy']))
plt.legend(['accuracy', 'val_accuracy'])
plt.ylim([0, 100])
plt.xlabel('Epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')

# %%
# Confusion Matrix
y_pred=model.predict(X_test)
y_pred = tf.argmax(y_pred, axis=1)
y_true = tf.concat(y_test, axis=0)
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=label_list,
            yticklabels=label_list,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
# Out:
# 70/70 [==============================] - 1s 10ms/step

# %% [markdown]
# Extracting mfcc from a single audio file and using it for prediction

# %%
audio_file = str(input())# Input the PATH containing the audio file to be tested with
audio_file = pathlib.Path(audio_file)

signal,sr = librosa.load(audio_file,sr=16000)

mfccs = librosa.feature.mfcc(y = signal,n_mfcc=13,sr = sr)


max_length=100
if len(mfccs[0]) < max_length:
   mfccs = np.pad(mfccs, ((0, 0), (0, max_length - len(mfccs[0]))), mode='constant')
else:
   mfccs = mfccs[:, :max_length]

mfccs=mfccs.reshape(mfccs.shape[0], mfccs.shape[1], 1)

mfccs=np.array(mfccs)

mfccs=mfccs[np.newaxis,:]

mfccs.shape

# %%
# Predicting using the first model
x=model.predict(mfccs)

plt.bar(label_list, tf.nn.softmax(x[0]))

plt.show()

# %% [markdown]
# Saving the model using Keras saved model

# %%
model.save("saved_mfcc")
# Out:
# INFO:tensorflow:Assets written to: saved_mfcc\assets
# INFO:tensorflow:Assets written to: saved_mfcc\assets

# %%
loaded_model = models.load_model("saved_mfcc")

# %% [markdown]
# MAKING A REAL-TIME INFERENCING FOR THE ABOVE MODELS

# %%
FRAMES_PER_BUFFER = 3200
FORMAT = pyaudio.paInt16 # -32768 to 32767
CHANNELS = 1
RATE = 16000
p = pyaudio.PyAudio()

# Record a time interval for 1 second
def record():
 stream = p.open(
    format=FORMAT,
    channels=CHANNELS,
    rate=RATE,
    input=True,
    frames_per_buffer=FRAMES_PER_BUFFER
 )

 frames = []
 seconds = 1
 for i in range(0, int(RATE / FRAMES_PER_BUFFER * seconds)):
        data = stream.read(FRAMES_PER_BUFFER)#input from the user
        frames.append(data)
 stream.stop_stream()
 stream.close()
 return np.frombuffer(b''.join(frames), dtype=np.int16)

# %%
# Making the MFCC's shape suitable to be an input for the models
def preprocessing(audio):
    audio=np.array([i/32768 for i in audio])
    audio = librosa.util.fix_length(audio, size=16000)
    audio=np.array(audio)
    mfccs=librosa.feature.mfcc(y=audio,sr=16000,n_mfcc=13)
    mfccs=mfccs.reshape(mfccs.shape[0], mfccs.shape[1], 1)
    mfccs=np.array(mfccs)
    mfccs=mfccs[np.newaxis,:]
    return mfccs

# %%
# Prediction function
def predict_mic():
    audio = record()
    spec = preprocessing(audio)
    prediction = loaded_model(spec)
    label_pred = np.argmax(prediction, axis=1)
    command = label_list[label_pred[0]]
    print('===============================================')
    print("Predicted label :", command)
    print('===============================================')
    return command

# MAIN FUNCTION
if __name__ == "__main__":
    while True:
        command=predict_mic()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(loaded_model)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter._experimental_lower_tensor_list_ops = False

# %%
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\sayan\AppData\Local\Temp\tmpmzhkiu2k\assets
# INFO:tensorflow:Assets written to: C:\Users\sayan\AppData\Local\Temp\tmpmzhkiu2k\assets

# %%
with open('converted_model.h', 'wb') as f:
    f.write(tflite_model)
